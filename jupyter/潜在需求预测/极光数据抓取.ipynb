# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 100)

#显示所有行

pd.set_option('display.max_rows', 100)

import warnings
warnings.filterwarnings("ignore")
import xgboost as xgb
from xgboost import plot_importance
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np

import sys
import time
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import datetime
import warnings
import feather
warnings.filterwarnings("ignore")
import math
sys.path.append('/data/apps/modules/jupyter')
from helper.spark_helper import *
from helper.presto_helper import query_presto
from helper.csv_helper import *
from helper.pandas_helper import *
from helper.presto_helper import query_hive_wy
citys='196'
user_pref_df = get_df_from_csv_table(query_presto(f'''
    select city_id,user_id, cur_date, order_count_d,order_days_30d,if(order_days_30d>5,1,0) as pref
    from dws.dws_pt_user_picture_da
    where city_id in ({citys}) and event_day between '20210201' and '20210407'
''')).dropna()

# %%
user_pref_df.shape
# Out:
# (13418475, 6)

# %%
user_pref_df.order_count_d.sum()
# Out:
# 1017150.0

# %%
user_pref_df['cur_date1'] = pd.to_datetime(user_pref_df['cur_date'])
user_pref_df.head()
# Out:
#    city_id  user_id                 cur_date  order_count_d  order_days_30d  \
# 0      196  2224193  2021-04-05 00:00:00.000            0.0             0.0
# 1      196  4112789  2021-04-05 00:00:00.000            0.0             0.0
# 2      196  4143563  2021-04-05 00:00:00.000            0.0             0.0
# 3      196  4161029  2021-04-05 00:00:00.000            0.0             8.0
# 4      196  4938692  2021-04-05 00:00:00.000            0.0             0.0
#
#    pref  cur_date1
# 0     0 2021-04-05
# 1     0 2021-04-05
# 2     0 2021-04-05
# 3     1 2021-04-05
# 4     0 2021-04-05

# %%
user_pref_df['month'] = pd.DatetimeIndex(pd.to_datetime(user_pref_df['cur_date1'])).month
user_pref_df.head()
# Out:
#    user_id                 cur_date  order_count_d  order_days_30d  pref  \
# 0  4200061  2021-04-07 00:00:00.000            1.0             5.0     0
# 1  6865117  2021-04-07 00:00:00.000            0.0             1.0     0
# 2  6889987  2021-04-07 00:00:00.000            0.0             0.0     0
# 3  6950268  2021-04-07 00:00:00.000            0.0             0.0     0
# 4  7165739  2021-04-07 00:00:00.000            3.0            13.0     1
#
#    cur_date1  month
# 0 2021-04-07      4
# 1 2021-04-07      4
# 2 2021-04-07      4
# 3 2021-04-07      4
# 4 2021-04-07      4

# %%
user_pref_df['year'] = pd.DatetimeIndex(pd.to_datetime(user_pref_df['cur_date1'])).year
user_pref_df.head()
# Out:
#    user_id                 cur_date  order_count_d  order_days_30d  pref  \
# 0  4200061  2021-04-07 00:00:00.000            1.0             5.0     0
# 1  6865117  2021-04-07 00:00:00.000            0.0             1.0     0
# 2  6889987  2021-04-07 00:00:00.000            0.0             0.0     0
# 3  6950268  2021-04-07 00:00:00.000            0.0             0.0     0
# 4  7165739  2021-04-07 00:00:00.000            3.0            13.0     1
#
#    cur_date1  month  year
# 0 2021-04-07      4  2021
# 1 2021-04-07      4  2021
# 2 2021-04-07      4  2021
# 3 2021-04-07      4  2021
# 4 2021-04-07      4  2021

# %%
user_pref_df['day'] = pd.DatetimeIndex(pd.to_datetime(user_pref_df['cur_date1'])).day
user_pref_df.head()
# Out:
#    user_id                 cur_date  order_count_d  order_days_30d  pref  \
# 0  4200061  2021-04-07 00:00:00.000            1.0             5.0     0
# 1  6865117  2021-04-07 00:00:00.000            0.0             1.0     0
# 2  6889987  2021-04-07 00:00:00.000            0.0             0.0     0
# 3  6950268  2021-04-07 00:00:00.000            0.0             0.0     0
# 4  7165739  2021-04-07 00:00:00.000            3.0            13.0     1
#
#    cur_date1  month  year  day
# 0 2021-04-07      4  2021    7
# 1 2021-04-07      4  2021    7
# 2 2021-04-07      4  2021    7
# 3 2021-04-07      4  2021    7
# 4 2021-04-07      4  2021    7

# %%
user_pref_df['week'] = pd.DatetimeIndex(pd.to_datetime(user_pref_df['cur_date1'])).week
user_pref_df.head()
# Out:
#    user_id                 cur_date  order_count_d  order_days_30d  pref  \
# 0  4200061  2021-04-07 00:00:00.000            1.0             5.0     0
# 1  6865117  2021-04-07 00:00:00.000            0.0             1.0     0
# 2  6889987  2021-04-07 00:00:00.000            0.0             0.0     0
# 3  6950268  2021-04-07 00:00:00.000            0.0             0.0     0
# 4  7165739  2021-04-07 00:00:00.000            3.0            13.0     1
#
#    cur_date1  month  year  day  week
# 0 2021-04-07      4  2021    7    14
# 1 2021-04-07      4  2021    7    14
# 2 2021-04-07      4  2021    7    14
# 3 2021-04-07      4  2021    7    14
# 4 2021-04-07      4  2021    7    14

# %%
user_pref_df.shape
# Out:
# (302769, 10)

# %%
user_pref_df[user_pref_df.user_id==2044893]
# Out:
#         user_id                 cur_date  order_count_d  order_days_30d  pref  \
# 67937   2044893  2021-04-07 00:00:00.000            0.0             4.0     0
# 256967  2044893  2021-04-05 00:00:00.000            0.0             3.0     0
# 297406  2044893  2021-04-06 00:00:00.000            2.0             4.0     0
#
#         cur_date1  month  year  day  week
# 67937  2021-04-07      4  2021    7    14
# 256967 2021-04-05      4  2021    5    14
# 297406 2021-04-06      4  2021    6    14

# %%
od=user_pref_df.groupby(['user_id','city_id']).order_count_d.sum().reset_index()

# %%
od[od.user_id==2044893]
# Out:
#     user_id  order_count_d
# 26  2044893            9.0

# %%
detail_df=get_df_from_csv_table(query_presto(f'''
    select user_id,bike_sn,city_id
    from dwd.dwd_bd_order_detail_da
    where city_id=196 and event_day between '20201001' and '20210407'
'''))

# %%
detail_df.shape
# Out:
# (1349581, 3)

# %%
detail_df[detail_df.user_id==2044893]
# Out:
#         user_id    bike_sn
# 455     2044893  812213792
# 42451   2044893  802213797
# 61667   2044893  812217214
# 72578   2044893  812211465
# 102101  2044893  802211660
# 108734  2044893  812211469
# 108755  2044893  802214719
# 117708  2044893  802213795
# 166815  2044893  812213792

# %%
detail_df.head()
# Out:
#     user_id    bike_sn  city_id
# 0   7967634  812211670      196
# 1   7206012  802214067      196
# 2  27700953  812212191      196
# 3  49256175  812210707      196
# 4  21175399  812216664      196

# %%
cnt_df=detail_df.groupby(['user_id','city_id']).count().reset_index()

# %%
cnt_df
# Out:
#         user_id  bike_sn
# 0       1758254        7
# 1       1888917        3
# 2       2039255        2
# 3       2044893        9
# 4       2177414        4
# 5       2205068        6
# 6       2210328        1
# 7       2325725       10
# 8       2342723        2
# 9       2344749        2
# 10      2346996       16
# 11      2363002       10
# 12      2366724       37
# 13      2404830        2
# 14      2425340        2
# 15      2434520        7
# 16      2487236        2
# 17      2677758       18
# 18      2736479        2
# 19      2768759        1
# 20      2781581        2
# 21      2832051        2
# 22      2844124        3
# 23      2932802       12
# 24      3014971        2
# 25      3034258        4
# 26      3324466        1
# 27      3341157        5
# 28      3367998        2
# 29      3378705        2
# 30      3450989        3
# 31      3467241        3
# 32      3569821       10
# 33      3640649        5
# 34      3655735       49
# 35      3709632        8
# ...

# %%
cnt_df[['bike_sn']].describe()
# Out:
#             bike_sn
# count  27948.000000
# mean       9.029913
# std       13.064983
# min        1.000000
# 25%        2.000000
# 50%        4.000000
# 75%       10.000000
# max      206.000000

# %%
cnt_df['bike_sn'].sum()
# Out:
# 252368

# %%
user_pref_df[user_pref_df.user_id==43127196]['order_count_d'].sum()
# Out:
# 206.0

# %%
od2=user_pref_df.groupby(['user_id']).sum().reset_index()

# %%
cnt_df.head()
# Out:
#    user_id  bike_sn
# 0  1758254        7
# 1  1888917        3
# 2  2039255        2
# 3  2044893        9
# 4  2177414        4

# %%
merge_df=od.merge(cnt_df,on=['user_id','city_id'],how='left')

# %%
merge_df
# Out:
#          user_id  city_id  order_count_d  bike_sn
# 0         923219      196            0.0      NaN
# 1         946294      196            0.0      NaN
# 2        1026996      196            0.0      NaN
# 3        1071779      196            0.0      NaN
# 4        1119499      196            0.0      NaN
# 5        1206788      196            0.0      NaN
# 6        1426690      196            0.0      NaN
# 7        1544056      196            0.0      NaN
# 8        1641126      196            0.0      NaN
# 9        1657627      196            0.0      NaN
# 10       1659872      196            0.0      NaN
# 11       1700392      196            0.0      NaN
# 12       1714167      196            0.0      NaN
# 13       1734281      196            0.0      NaN
# 14       1734498      196            0.0      NaN
# 15       1758254      196            7.0      7.0
# 16       1776258      196            0.0      NaN
# 17       1778597      196            0.0      NaN
# ...

# %%
merge_df=merge_df.fillna(0)

# %%
merge_df=merge_df.dropna()

# %%
merge_df

# %%
merge_df['order_count_d'].sum()
# Out:
# 248259.0

# %%
merge_df['bike_sn'].sum()
# Out:
# 249099.0

# %%
cnt_df.shape
# Out:
# (27948, 2)

# %%
od2.shape
# Out:
# (102605, 4)

# %%
a=cnt_df['user_id'].tolist()

# %%
b=od2['user_id'].tolist()

# %%
c=list(set(a).difference(set(b)))

# %%
c
# Out:
# [7176199,
#  4104201,
#  31084554,
#  8091659,
#  7194634,
#  7215118,
#  19970062,
#  24408088,
#  34850841,
#  27428891,
#  15247389,
#  34574365,
#  18069538,
#  5627939,
#  34492452,
#  14467110,
#  4309032,
#  20107311,
#  7219248,
#  4442159,
#  5744698,
#  9084987,
#  17389628,
#  7206983,
#  48758856,
#  8376393,
#  8742988,
#  7145562,
#  6660194,
#  8593509,
#  18835558,
#  4130926,
#  44046448,
#  5914736,
#  19712113,
#  20125811,
#  8091760,
#  6963317,
#  31107190,
#  4624503,
#  14262387,
#  28498042,
#  14434428,
#  30683261,
#  36685951,
#  7037059,
#  6664324,
#  45162637,
#  26740878,
#  21524624,
#  39934098,
#  48674963,
#  6977684,
#  6959253,
#  7379093,
#  42428568,
#  7168153,
#  10471576,
#  6854811,
#  7266460,
#  43569309,
#  9846954,
#  7127210,
#  28530860,
#  32786610,
#  14512309,
#  39751863,
#  20811961,
#  6854846,
#  14448831,
#  18655422,
#  7915713,
#  37714110,
#  5490898,
#  8001754,
#  5284060,
#  33861854,
#  7084255,
#  8188132,
# ...

# %%
od2[od2.user_id==7176199]
# Out:
# Empty DataFrame
# Columns: [user_id, order_count_d, order_days_30d, pref]
# Index: []

# %%
get_df_from_csv_table(query_presto(f'''
    select count(order_id)
    from dwd.dwd_bd_order_detail_da
    where city_id=227 and event_day between '20210301' and '20210406'
'''))
# Out:
#     _col0
# 0  280877

# %%
get_df_from_csv_table(query_presto(f'''
    select sum(order_count_d)
    from dws.dws_pt_user_picture_da
    where city_id in (227) and event_day between '20210301' and '20210406'
'''))
# Out:
#     _col0
# 0  280852

# %%
merge_df2=od2.merge(cnt_df,on='user_id',how='left')
merge_df2=merge_df2.dropna()

# %%
merge_df2['order_count_d'].sum()
# Out:
# 248259.0

# %%
merge_df2['bike_sn'].sum()
# Out:
# 249099.0

# %%
merge_df2
# Out:
#          user_id  order_count_d  order_days_30d  pref  bike_sn
# 15       1758254            7.0            30.0     1      7.0
# 18       1888917            3.0            15.0     0      3.0
# 24       2039255            2.0            47.0     0      2.0
# 26       2044893            9.0            33.0     0      9.0
# 31       2177414            4.0           125.0     0      4.0
# 32       2205068            6.0            86.0     0      6.0
# 33       2210328            1.0            21.0     0      1.0
# 38       2325725           10.0           308.0    34     10.0
# 43       2342723            2.0             2.0     0      2.0
# 45       2344749            2.0            54.0     0      2.0
# 46       2346996           16.0            85.0     3     16.0
# 47       2363002           10.0           266.0    20     10.0
# 48       2366724           37.0           374.0    34     37.0
# 52       2404830            2.0            27.0     0      2.0
# ...

# %%
merge_df2[merge_df2.order_count_d!=merge_df2.bike_sn]
# Out:
#          user_id  order_count_d  order_days_30d  pref  bike_sn
# 71       2736479            0.0             0.0     0      2.0
# 77       2781581            7.0           147.0    19      2.0
# 116      3341157           13.0           162.0    10      5.0
# 127      3569821           15.0           141.0    13     10.0
# 205      4091957            3.0            34.0     0      1.0
# 256      4113367            2.0            71.0     8      7.0
# 261      4114599            2.0            32.0     0      4.0
# 266      4114946            2.0             2.0     0      3.0
# 288      4119742           15.0           242.0    33     10.0
# 293      4120710            2.0            91.0     0      1.0
# 332      4132831           11.0           298.0    34      8.0
# 388      4155696            3.0           105.0    11      1.0
# 391      4156218            5.0           154.0     1      1.0
# 405      4159846            8.0           245.0    20      7.0
# ...

# %%
get_df_from_csv_table(query_presto(f'''
    select order_id,event_day,city_id,user_id
    from dwd.dwd_bd_order_detail_da
    where city_id=196 and event_day between '20210301' and '20210406' and user_id=2781581
'''))
# Out:
#               order_id event_day  city_id  user_id
# 0  2103203989823979585  20210320      196  2781581
# 1  2103204111089696772  20210320      196  2781581

# %%
get_df_from_csv_table(query_presto(f'''
    select order_count_d,city_id,user_id,event_day
    from dws.dws_pt_user_picture_da
    where city_id=196 and event_day between '20210301' and '20210406' and user_id=2781581
'''))
# Out:
#     order_count_d  city_id  user_id event_day
# 0               0      196  2781581  20210405
# 1               0      196  2781581  20210406
# 2               0      196  2781581  20210403
# 3               0      196  2781581  20210330
# 4               0      196  2781581  20210402
# 5               0      196  2781581  20210401
# 6               0      196  2781581  20210404
# 7               0      196  2781581  20210331
# 8               0      196  2781581  20210329
# 9               0      196  2781581  20210326
# 10              0      196  2781581  20210325
# 11              0      196  2781581  20210328
# 12              2      196  2781581  20210327
# 13              0      196  2781581  20210324
# 14              0      196  2781581  20210323
# 15              0      196  2781581  20210322
# 16              0      196  2781581  20210321
# 17              3      196  2781581  20210320

# %%
jiguang_df=pd.read_csv('iaudience.csv').rename({'imei/phone/mac/imsi':'mobile'},axis=1)

# %%
col=list(jiguang_df.columns)

# %%
col_use=[]
for _ in col:
    if jiguang_df[_].count()>jiguang_df.shape[0]/5:
        col_use.append(_)
        print(_,':',jiguang_df[_].count())
# Out:
# mobile : 30132
# 查询结果 : 30132
# CPL_HHM_CHILD_HC : 16041
# CPL_INDM_GEND_S : 22537
# CPL_INDM_MARRC2 : 22520
# CPL_INDM_NATI : 20633
# CPL_INDM_AGE_C5 : 22039
# CPL_HHM_CHILD_CHLI : 16041
# CID_MODEL : 23748
# CPL_DVM_BRAD : 22903
# CPL_DVM_HF : 24076
# CPL_DVM_ISP : 18865
# CPL_DVM_OS : 23749
# CPL_DVM_PUPR : 23037
# CPL_DVM_RESO : 23502
# CPL_DVM_SCSIZE : 23488
# CPL_DVM_TIME : 22976
# CPL_DVM_TYPE : 23098
# FIM_FISM_CONL_CIR : 13892
# FIM_FISM_INCL : 12999
# GBM_BHM_PURB_CONP : 18902
# GBM_BHM_PURB_PREF : 20761
# SOM_OCM_CAREER : 14585
# GBM_HBM_S : 19033
# GBM_BHM_APPP_APPR_S : 19690
# GBM_BHM_PURB_PURW : 17339
# GBM_BHM_PURB_SUPR : 19102
# GBM_BHM_REAB_REAP : 20791
# APP_HOBY_SHORT_VIDEO : 17156
# APP_HOBY_SUMMARY_VIDEO : 18616
# APP_HOBY_SELF_PHOTO : 18766
# APP_HOBY_SUNMMARY_NEWS : 12121
# APP_HOBY_SPEED_GAME : 9683
# APP_HOBY_WIFI : 14995
# APP_HOBY_FOOD : 11216
# APP_HOBY_RECORD : 13245
# APP_HOBY_HOT_SOCIAL : 19412
# APP_HOBY_ONLINE_STUDY : 7306
# ...

# %%
jiguang_df.shape
# Out:
# (30132, 340)

# %%
#百度坐标转高德坐标
def read_key():
    """  持久化key,便于读取 """
    key_path = os.path.join('user-key')
    print(key_path)
    with open(key_path, 'r', encoding='utf-8') as f:
        key = f.read()
        print(key)
    return key
# read_key()

import requests
def request_url_get(url):
    """ 请求url方法get方法 """
    try:
        r = requests.get(url=url, timeout=30)
        if r.status_code == 200:
            return r.text
        return None
    except RequestException:
        print('请求url返回错误异常')
        return None
    
# https://restapi.amap.com/v3/assistant/coordinate/convert?parameters
import json
def parse_json(content_json):
    """  解析json函数 """
    result_json = json.loads(content_json)
    return result_json

def request_api(url):
    """ 请求高德api 解析json """
    result = request_url_get(url)
    result_json = parse_json(result)
    return result_json

def run():
    """ 运行函数 """
#     locations = (test_df['start_lng'][0],test_df['start_lat'][0])
    coordsys = 'baidu'
    lng=104.158337
    lat=30.004660
    key = read_key()
 
    index_url=f'https://restapi.amap.com/v3/assistant/coordinate/convert?'\
         f'key={key}&locations={lng},{lat}&coordsys={coordsys}'
    
#     index_url=f'https://restapi.amap.com/v3/assistant/coordinate/convert?'\
#             f'key={key}&locations=104.158337,30.004660&coordsys=baidu'

    index_result = request_api(index_url)

    print(index_result)
    print(index_result['locations'])
    
# run()

# %%
index_url='https://api.data.jiguang.cn/v5/users?phone=18622876058&tag=all'
index_result = request_api(index_url)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-c04dd43587a7> in <module>
#       1 index_url='https://api.data.jiguang.cn/v5/users?phone=18622876058&tag=all'
# ----> 2 index_result = request_api(index_url)
#
# <ipython-input-1-434ca21a5cc8> in request_api(url)
#      32     """ 请求高德api 解析json """
#      33     result = request_url_get(url)
# ---> 34     result_json = parse_json(result)
#      35     return result_json
#      36
#
# <ipython-input-1-434ca21a5cc8> in parse_json(content_json)
#      26 def parse_json(content_json):
#      27     """  解析json函数 """
# ---> 28     result_json = json.loads(content_json)
#      29     return result_json
#      30
#
# /usr/local/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
# ...

# %%
# !/usr/bin/env python3
# -*- coding: utf-8 -*-

from requests import get
from base64 import b64encode
import json

if __name__ == '__main__':
    devKey = b''
    devSecret = b''
    params = {
        'phone': 'xxxxxxxxxxx',
        'tag': 'all'
    }

    base64_auth_string = (b64encode(devKey + b':' + devSecret)).decode()
    headers = {'Authorization': f'Basic {base64_auth_string}'}
    response = get('https://api.data.jiguang.cn/v5/users', headers=headers, params=params)
    print(response.request.headers)
    print(json.dumps(json.loads(response.text), indent=4))
# Out:
# {'User-Agent': 'python-requests/2.21.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'Authorization': 'Basic Og=='}
# {
#     "code": 4001,
#     "message": "auth header not right: Basic Og==",
#     "req_id": "c43c68d2ae3cc832"
# }

# %%
devKey = b''
devSecret = b''

# %%
from requests import get
from base64 import b64encode
import json
base64_auth_string = str(b64encode(devKey + b':' + devSecret))

# %%
base64_auth_string
# Out:
# "b'Og=='"

# %%
{'Authorization': f'Basic {base64_auth_string}'}
# Out:
# {'Authorization': "Basic b'Og=='"}

# %%
get('https://api.data.jiguang.cn/v5/users', headers=headers, params=params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-42e241721945> in <module>
# ----> 1 get('https://api.data.jiguang.cn/v5/users', headers=headers, params=params)
#
# NameError: name 'headers' is not defined

# %%
from requests import get
from base64 import b64encode
import json

if __name__ == '__main__':
    devKey = b'92b272ae27c69ad714f471a9'
    devSecret = b'7888db2627e681c2dacbde7d'
    params = {
        'phone': 'xxxxxxxxxxx',
        'tag': 'all'
    }

    base64_auth_string = (b64encode(devKey + b':' + devSecret)).decode()
    print(base64_auth_string)
    headers = {'Authorization': f'Basic {base64_auth_string}'}
    response = get('https://api.data.jiguang.cn/v5/users', headers=headers, params=params)
    print(response.request.headers)
    js_response = json.loads(response.text)
    print(json.dumps(js_response, indent=4))
# Out:
# OTJiMjcyYWUyN2M2OWFkNzE0ZjQ3MWE5Ojc4ODhkYjI2MjdlNjgxYzJkYWNiZGU3ZA==
# {'User-Agent': 'python-requests/2.21.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'Authorization': 'Basic OTJiMjcyYWUyN2M2OWFkNzE0ZjQ3MWE5Ojc4ODhkYjI2MjdlNjgxYzJkYWNiZGU3ZA=='}
# {
#     "code": 4002,
#     "message": "\u7528\u6237\u65e0\u6743\u9650\u8bbf\u95ee\u6b64API",
#     "req_id": "d96cb103291d9ff2"
# }

# %%
https://report.jpush.cn/v3/received/detail?msg_ids=1613113584,1229760629 -u "7d431e42dfa6a6d693ac2d04:5e987ac6d2e04d95a9d8f0d1"

# %%
from requests import get
from base64 import b64encode
import json

if __name__ == '__main__':
    devKey = b'7d431e42dfa6a6d693ac2d04'
    devSecret = b'5e987ac6d2e04d95a9d8f0d1'
    params = {
#         'phone': 'xxxxxxxxxxx',
#         'tag': 'all'
        'msg_ids':'1613113584,1229760629',
    }

    base64_auth_string = (b64encode(devKey + b':' + devSecret)).decode()
    print(base64_auth_string)
    headers = {'Authorization': f'Basic {base64_auth_string}'}
    response = get('https://report.jpush.cn/v3/received/detail', headers=headers, params=params)
    print(response.request.headers)
    js_response = json.loads(response.text)
    print(json.dumps(js_response, indent=4))
# Out:
# N2Q0MzFlNDJkZmE2YTZkNjkzYWMyZDA0OjVlOTg3YWM2ZDJlMDRkOTVhOWQ4ZjBkMQ==
# {'User-Agent': 'python-requests/2.21.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'Authorization': 'Basic N2Q0MzFlNDJkZmE2YTZkNjkzYWMyZDA0OjVlOTg3YWM2ZDJlMDRkOTVhOWQ4ZjBkMQ=='}
# [
#     {
#         "android_pns_received": null,
#         "android_pns_sent": null,
#         "ios_apns_received": null,
#         "ios_apns_sent": null,
#         "ios_msg_received": null,
#         "jpush_received": null,
#         "msg_id": "1613113584",
#         "quickapp_jpush_received": null,
#         "quickapp_pns_sent": null,
#         "wp_mpns_sent": null
#     },
#     {
#         "android_pns_received": null,
#         "android_pns_sent": null,
#         "ios_apns_received": null,
#         "ios_apns_sent": null,
#         "ios_msg_received": null,
#         "jpush_received": null,
#         "msg_id": "1229760629",
#         "quickapp_jpush_received": null,
# ...

# %%
user_pref_df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-88ca4c4a2439> in <module>
# ----> 1 user_pref_df.shape
#
# NameError: name 'user_pref_df' is not defined

# %%
import datetime
import time

# %%
datetime.date()
# Out:
# datetime.date

# %%
localtime = time.localtime(time.time())

# %%
localtime
# Out:
# time.struct_time(tm_year=2021, tm_mon=4, tm_mday=12, tm_hour=11, tm_min=45, tm_sec=42, tm_wday=0, tm_yday=102, tm_isdst=0)

# %%
localtime['tm_year']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-f4ee39c1f4d3> in <module>
# ----> 1 localtime['tm_year']
#
# TypeError: tuple indices must be integers or slices, not str

# %%
# 年月日时分秒 "%Y-%m-%d %H-%M-%S" 
time.strftime("%Y",time.localtime(time.time()))
# Out:
# '2021'

# %%
import pandas as pd
df=pd.read_csv('jg_sg_df3.csv')

# %%
df.window.value_counts()
# Out:
# 8.0    9851
# 7.0    7745
# 6.0    2714
# 5.0    1392
# 2.0    1091
# 4.0     846
# 3.0     509
# 1.0     462
# Name: window, dtype: int64

# %%
def get_pref(x):
    if x<=4: 
        return 1
    elif x==7: 
        return 0 
    else:
        return -1
df['pref1']=df.window.apply(get_pref)

# %%
df['pref1'].value_counts()
# Out:
# -1    13957
#  0     7745
#  1     2908
# Name: pref1, dtype: int64

# %%
sql=f"""
    select id,name
    from ods.ods_ebike_city_df
     where event_day='{event_day}' and open=1"""

dfff=get_df_from_csv_table(query_presto(f"""select * from ods.ods_ebike_city_df where event_day='20210412'"""))
dfff.shape
# Out:
# (768, 33)

# %%
date_tmp=(datetime.date.today() + datetime.timedelta(days=-1)).strftime('%Y-%m-%d')
date_tmp
# Out:
# '2021-04-12'

# %%
from helper.presto_helper import *
from helper.csv_helper import *
from helper.pandas_helper import *

df2=get_df_from_csv_table(query_presto(f"""select * from ai.dws_ai_jw_physics_move_car_da where event_day='20210413'"""))
df2.shape
# Out:
# (0, 6)

# %%
import datetime
import time
# time.strftime("%Y-%m-%d",time.localtime(time.time()))

# %%
time.strftime("%Y-%m-%d",time.localtime(time.time()))
# Out:
# '2021-04-12'

# %%
''.join(datetime.date.today().strftime('%Y-%m-%d').split('-'))
# Out:
# '20210412'

# %%
today=datetime.date.today() 
start_date_tmp=(today + datetime.timedelta(days=-29)).strftime('%Y-%m-%d')

start_date = ''.join(start_date_tmp.split('-'))
end_date = ''.join(today.strftime('%Y-%m-%d').split('-'))


event_day = end_date
# Out:
# '20210412'

# %%
(datetime.date.today() + datetime.timedelta(days=-29)).strftime('%Y-%m-%d')
# Out:
# '2021-03-14'

# %%
df2
# Out:
#        city_name  station_id  station_type    cur_date event_day  city_id
# 0            桐柏县        3351             2  2021-03-17  20210316       98
# 1            上饶县       73736             2  2021-03-17  20210316       95
# 2            上饶县       73758             2  2021-03-17  20210316       95
# 3            上饶县       56112             2  2021-03-17  20210316       95
# 4            桐柏县       32035             2  2021-03-17  20210316       98
# 5            上饶县       73919             1  2021-03-17  20210316       95
# 6            上饶县        4339             2  2021-03-17  20210316       95
# 7            上饶县       73924             2  2021-03-17  20210316       95
# 8            桐柏县      152542             2  2021-03-17  20210316       98
# 9            桐柏县        9095             2  2021-03-17  20210316       98
# 10           上饶县       91464             2  2021-03-17  20210316       95
# 11           上饶县        3706             2  2021-03-17  20210316       95
# ...
